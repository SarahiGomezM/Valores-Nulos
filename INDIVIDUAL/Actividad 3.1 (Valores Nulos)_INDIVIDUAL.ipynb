# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga desde un archivo .csv sin indice
data1 = pd.read_csv('Ventas_totales.csv')

# %%
#Identificar valores nulos por columna
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# indice_tiempo                           0
# ventas_precios_corrientes               0
# ventas_precios_constantes               0
# ventas_totales_canal_venta              0
# salon_ventas                            6
# canales_on_line                         0
# ventas_totales_medio_pago               0
# efectivo                                0
# tarjetas_debito                         1
# tarjetas_credito                        7
# otros_medios                            1
# ventas_totales_grupo_articulos          0
# subtotal_ventas_alimentos_bebidas      10
# bebidas                                 1
# almacen                                 2
# panaderia                               1
# lacteos                                 1
# carnes                                  1
# verduleria_fruteria                     1
# alimentos_preparados_rotiseria          1
# articulos_limpieza_perfumeria           0
# indumentaria_calzado_textiles_hogar     2
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   indice_tiempo                        65 non-null     object
#  1   ventas_precios_corrientes            65 non-null     float64
#  2   ventas_precios_constantes            65 non-null     float64
#  3   ventas_totales_canal_venta           65 non-null     float64
#  4   salon_ventas                         59 non-null     float64
#  5   canales_on_line                      65 non-null     float64
#  6   ventas_totales_medio_pago            65 non-null     float64
#  7   efectivo                             65 non-null     float64
#  8   tarjetas_debito                      64 non-null     float64
#  9   tarjetas_credito                     58 non-null     float64
#  10  otros_medios                         64 non-null     float64
# ...

# %%
#Realizamos una copia del dataframe
data1_1=data1.copy()

# %%
#Método de sustitución de valores nulos
#Sustituir valores nulos con promedio o media
data1["salon_ventas"]=data1["salon_ventas"].fillna(round(data1_1["salon_ventas"].mean(),1))

# %%
#Corroboramos valores nulos
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# indice_tiempo                           0
# ventas_precios_corrientes               0
# ventas_precios_constantes               0
# ventas_totales_canal_venta              0
# salon_ventas                            0
# canales_on_line                         0
# ventas_totales_medio_pago               0
# efectivo                                0
# tarjetas_debito                         1
# tarjetas_credito                        7
# otros_medios                            1
# ventas_totales_grupo_articulos          0
# subtotal_ventas_alimentos_bebidas      10
# bebidas                                 1
# almacen                                 2
# panaderia                               1
# lacteos                                 1
# carnes                                  1
# verduleria_fruteria                     1
# alimentos_preparados_rotiseria          1
# articulos_limpieza_perfumeria           0
# indumentaria_calzado_textiles_hogar     2
# ...

# %%
#Método de sustitución de valores nulos
#Sustituir valores nulos por un string en  concreto 
data1["tarjetas_debito"] =data1["tarjetas_debito"].fillna("0") 
data1
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Corroboramos valores nulos
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# indice_tiempo                           0
# ventas_precios_corrientes               0
# ventas_precios_constantes               0
# ventas_totales_canal_venta              0
# salon_ventas                            0
# canales_on_line                         0
# ventas_totales_medio_pago               0
# efectivo                                0
# tarjetas_debito                         0
# tarjetas_credito                        7
# otros_medios                            1
# ventas_totales_grupo_articulos          0
# subtotal_ventas_alimentos_bebidas      10
# bebidas                                 1
# almacen                                 2
# panaderia                               1
# lacteos                                 1
# carnes                                  1
# verduleria_fruteria                     1
# alimentos_preparados_rotiseria          1
# articulos_limpieza_perfumeria           0
# indumentaria_calzado_textiles_hogar     2
# ...

# %%
#Método de sustitución de valores nulos
#Sustituir valores nulos por un string en  concreto 
data1["tarjetas_credito"] =data1["tarjetas_credito"].fillna("0") 
data1
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Corroboramos valores nulos
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# indice_tiempo                           0
# ventas_precios_corrientes               0
# ventas_precios_constantes               0
# ventas_totales_canal_venta              0
# salon_ventas                            0
# canales_on_line                         0
# ventas_totales_medio_pago               0
# efectivo                                0
# tarjetas_debito                         0
# tarjetas_credito                        0
# otros_medios                            1
# ventas_totales_grupo_articulos          0
# subtotal_ventas_alimentos_bebidas      10
# bebidas                                 1
# almacen                                 2
# panaderia                               1
# lacteos                                 1
# carnes                                  1
# verduleria_fruteria                     1
# alimentos_preparados_rotiseria          1
# articulos_limpieza_perfumeria           0
# indumentaria_calzado_textiles_hogar     2
# ...

# %%
#Método de sustitución de valores nulos
#Sustituir valores nulos por un string en  concreto 
data1["otros_medios"] =data1["otros_medios"].fillna("0") 
data1
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Corroboramos valores nulos
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# indice_tiempo                           0
# ventas_precios_corrientes               0
# ventas_precios_constantes               0
# ventas_totales_canal_venta              0
# salon_ventas                            0
# canales_on_line                         0
# ventas_totales_medio_pago               0
# efectivo                                0
# tarjetas_debito                         0
# tarjetas_credito                        0
# otros_medios                            0
# ventas_totales_grupo_articulos          0
# subtotal_ventas_alimentos_bebidas      10
# bebidas                                 1
# almacen                                 2
# panaderia                               1
# lacteos                                 1
# carnes                                  1
# verduleria_fruteria                     1
# alimentos_preparados_rotiseria          1
# articulos_limpieza_perfumeria           0
# indumentaria_calzado_textiles_hogar     2
# ...

# %%
#Método de sustitución de valores nulos
#Sustituir valores nulos con promedio o media
data1["subtotal_ventas_alimentos_bebidas"]=data1["subtotal_ventas_alimentos_bebidas"].fillna(round(data1_1["subtotal_ventas_alimentos_bebidas"].mean(),1))

# %%
#Corroboramos valores nulos
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# indice_tiempo                          0
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                1
# almacen                                2
# panaderia                              1
# lacteos                                1
# carnes                                 1
# verduleria_fruteria                    1
# alimentos_preparados_rotiseria         1
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    2
# electronicos_articulos_hogar           3
# ...

# %%
#Método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
data1["bebidas"] =data1["bebidas"].fillna(method="ffill")
# Out:
# C:\Users\sarah\AppData\Local\Temp\ipykernel_19468\2593493831.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1["bebidas"] =data1["bebidas"].fillna(method="ffill")

# %%
#Corroboramos valores nulos
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# indice_tiempo                          0
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                2
# panaderia                              1
# lacteos                                1
# carnes                                 1
# verduleria_fruteria                    1
# alimentos_preparados_rotiseria         1
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    2
# electronicos_articulos_hogar           3
# ...

# %%
#Método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
data1["almacen"] =data1["almacen"].fillna(method="bfill")
# Out:
# C:\Users\sarah\AppData\Local\Temp\ipykernel_19468\1358841385.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1["almacen"] =data1["almacen"].fillna(method="bfill")

# %%
#Corroboramos valores nulos
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# indice_tiempo                          0
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              1
# lacteos                                1
# carnes                                 1
# verduleria_fruteria                    1
# alimentos_preparados_rotiseria         1
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    2
# electronicos_articulos_hogar           3
# ...

# %%
#Método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("bfill")
#Filtro por columnas
data1["panaderia"] =data1["panaderia"].fillna(method="bfill")
# Out:
# C:\Users\sarah\AppData\Local\Temp\ipykernel_19468\46944961.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1["panaderia"] =data1["panaderia"].fillna(method="bfill")

# %%
#Método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
data1["lacteos"] =data1["lacteos"].fillna(method="ffill")
# Out:
# C:\Users\sarah\AppData\Local\Temp\ipykernel_19468\2904773995.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1["lacteos"] =data1["lacteos"].fillna(method="ffill")

# %%
#Método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("bfill")
#Filtro por columnas
data1["carnes"] =data1["carnes"].fillna(method="bfill")
# Out:
# C:\Users\sarah\AppData\Local\Temp\ipykernel_19468\617608810.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1["carnes"] =data1["carnes"].fillna(method="bfill")

# %%
#Corroboramos valores nulos
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# indice_tiempo                          0
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              0
# lacteos                                0
# carnes                                 0
# verduleria_fruteria                    1
# alimentos_preparados_rotiseria         1
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    2
# electronicos_articulos_hogar           3
# ...

# %%
#Método de sustitución de valores nulos
#Sustituir valores nulos con promedio o media
data1["verduleria_fruteria"]=data1["verduleria_fruteria"].fillna(round(data1_1["verduleria_fruteria"].mean(),1))

# %%
#Método de sustitución de valores nulos
#Sustituir valores nulos con promedio o media
data1["alimentos_preparados_rotiseria"]=data1["alimentos_preparados_rotiseria"].fillna(round(data1_1["alimentos_preparados_rotiseria"].mean(),1))

# %%
#Método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("bfill")
#Filtro por columnas
data1["indumentaria_calzado_textiles_hogar"] =data1["indumentaria_calzado_textiles_hogar"].fillna(method="bfill")
# Out:
# C:\Users\sarah\AppData\Local\Temp\ipykernel_19468\757617866.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1["indumentaria_calzado_textiles_hogar"] =data1["indumentaria_calzado_textiles_hogar"].fillna(method="bfill")

# %%
#Corroboramos valores nulos
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# indice_tiempo                          0
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              0
# lacteos                                0
# carnes                                 0
# verduleria_fruteria                    0
# alimentos_preparados_rotiseria         0
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    0
# electronicos_articulos_hogar           3
# ...

# %%
#Método de sustitución de valores nulos
#Sustituir valores nulos con promedio o media
data1["electronicos_articulos_hogar"]=data1["electronicos_articulos_hogar"].fillna(round(data1_1["electronicos_articulos_hogar"].mean(),1))

# %%
#Método de sustitución de valores nulos
#Sustituir valores nulos con promedio o media
data1["otros"]=data1["otros"].fillna(round(data1_1["otros"].mean(),1))

# %%
#Corroboramos valores nulos
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# indice_tiempo                          0
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              0
# lacteos                                0
# carnes                                 0
# verduleria_fruteria                    0
# alimentos_preparados_rotiseria         0
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    0
# electronicos_articulos_hogar           0
# ...

# %%
#Corroboramos valores nulos en todo el dataframe
valores_nulos=data1.isnull().sum().sum()
valores_nulos
# Out:
# np.int64(0)

# %%
#Convertir DataFrame a CSV
data1.to_csv("Ventas_totales_LIMPIO.csv")
